# %%
# imports
import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import os
import sys
import importlib

from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt


sys.path.append("..") # not good
from tools.data import load_data_simc_v1, load_data_radioml_v1

physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
# Out:
# 2023-05-03 17:14:16.750279: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-03 17:14:16.778433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 17:14:17.279697: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-03 17:14:18.520591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:18.524890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:18.525048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Util functions

# %%
def set_seed(SEED):
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

def reload_module(m: str):
    importlib.reload(sys.modules[m])

# %% [markdown]
# ## Data loading

# %%
# Conatans
RADIO_ML_2016_A_DIR = "/development/data/RML2016.10a/RML2016.10a_dict.pkl" # radioml dataset
RADIO_ML_2016_B_DIR = "/development/data/RML2016.10b/RML2016.10b_dict.pkl" # radioml dataset
TRAIN_DATA_DIR = RADIO_ML_2016_A_DIR

MODEL_DATA_TYPE = np.float32

SEED = 123456
set_seed(SEED)

# %%
# Loading itself
labels, data, modulations = load_data_radioml_v1(TRAIN_DATA_DIR, to_1024=False)
print(modulations)
print(labels.shape)
print(data.shape)
# Out:
# ['AM-DSB', 'QAM64', 'GFSK', 'QPSK', 'QAM16', 'WBFM', 'PAM4', '8PSK', 'CPFSK', 'BPSK', 'AM-SSB']
# (220000,)
# (220000, 1, 128, 2)

# %%
# Data Ssplitting
DS_SIZE = len(labels)

n_train = int(0.8 * DS_SIZE)                # 80% - Train
n_validation = int(0.1 * DS_SIZE)           # 10% - Validation
n_test = DS_SIZE - n_train - n_validation   # 10% - Test

random_indecies = np.arange(DS_SIZE)
np.random.shuffle(random_indecies)

train_indecies, validation_indecies, test_indecies, _ = np.split(
    random_indecies, [int(DS_SIZE * 0.8), int(DS_SIZE * 0.9), DS_SIZE]
)

train_data, train_labels = data[train_indecies], labels[train_indecies]
validation_data, validation_labels = data[validation_indecies], labels[validation_indecies]
test_data, test_labels = data[test_indecies], labels[test_indecies]

# %%
# Should save some memory
# del data
# del labels

# %% [markdown]
# ## Model creation
# #### Parts of Encoder

# %% [markdown]
# ### 1. Multi Head Attention

# %%
from tensorflow import math, matmul, reshape, shape, transpose, cast, float32
from tensorflow.keras.layers import Dense, Layer
from keras.backend import softmax

# Implementing the Scaled-Dot Product Attention
class DotProductAttention(Layer):
    def __init__(self, **kwargs):
        super(DotProductAttention, self).__init__(**kwargs)

    def call(self, queries, keys, values, d_k, mask=None):
        # Scoring the queries against the keys after transposing the latter, and scaling
        scores = matmul(queries, keys, transpose_b=True) / math.sqrt(cast(d_k, float32))

        # Apply mask to the attention scores
        if mask is not None:
            scores += -1e9 * mask

        # Computing the weights by a softmax operation
        weights = softmax(scores)

        # Computing the attention by a weighted sum of the value vectors
        return matmul(weights, values)

# Implementing the Multi-Head Attention
class SIMC_MultiHeadAttention(Layer):
    def __init__(self, h, d_k, d_v, d_model, **kwargs):
        super(SIMC_MultiHeadAttention, self).__init__(**kwargs)
        self.attention = DotProductAttention()  # Scaled dot product attention
        self.heads = h  # Number of attention heads to use
        self.d_k = d_k  # Dimensionality of the linearly projected queries and keys
        self.d_v = d_v  # Dimensionality of the linearly projected values
        self.d_model = d_model  # Dimensionality of the model
        self.W_q = Dense(d_k)  # Learned projection matrix for the queries
        self.W_k = Dense(d_k)  # Learned projection matrix for the keys
        self.W_v = Dense(d_v)  # Learned projection matrix for the values
        self.W_o = Dense(d_model)  # Learned projection matrix for the multi-head output

    def reshape_tensor(self, x, heads, flag):
        if flag:
            # Tensor shape after reshaping and transposing: (batch_size, heads, seq_length, -1)
            x = reshape(x, shape=(shape(x)[0], shape(x)[1], heads, -1))
            x = transpose(x, perm=(0, 2, 1, 3))
        else:
            # Reverting the reshaping and transposing operations: (batch_size, seq_length, d_k)
            x = transpose(x, perm=(0, 2, 1, 3))
            x = reshape(x, shape=(shape(x)[0], shape(x)[1], self.d_k))
        return x

    def call(self, queries, keys, values, mask=None):
        # Rearrange the queries to be able to compute all heads in parallel
        q_reshaped = self.reshape_tensor(self.W_q(queries), self.heads, True)
        # Resulting tensor shape: (batch_size, heads, input_seq_length, -1)

        # Rearrange the keys to be able to compute all heads in parallel
        k_reshaped = self.reshape_tensor(self.W_k(keys), self.heads, True)
        # Resulting tensor shape: (batch_size, heads, input_seq_length, -1)

        # Rearrange the values to be able to compute all heads in parallel
        v_reshaped = self.reshape_tensor(self.W_v(values), self.heads, True)
        # Resulting tensor shape: (batch_size, heads, input_seq_length, -1)

        # Compute the multi-head attention output using the reshaped queries, keys and values
        o_reshaped = self.attention(q_reshaped, k_reshaped, v_reshaped, self.d_k, mask)
        # Resulting tensor shape: (batch_size, heads, input_seq_length, -1)

        # Rearrange back the output into concatenated form
        output = self.reshape_tensor(o_reshaped, self.heads, False)
        # Resulting tensor shape: (batch_size, input_seq_length, d_v)

        # Apply one final linear projection to the output to generate the multi-head attention
        # Resulting tensor shape: (batch_size, input_seq_length, d_model)
        return self.W_o(output)

# %% [markdown]
# ### 2. Encoder layer and Encoder itself

# %%
from tensorflow.keras.layers import LayerNormalization, Layer, Dense, ReLU, Dropout
# from multihead_attention import MultiHeadAttention
# from positional_encoding import PositionEmbeddingFixedWeights

# Implementing the Add & Norm Layer
class AddNormalization(Layer):
    def __init__(self, **kwargs):
        super(AddNormalization, self).__init__(**kwargs)
        self.layer_norm = LayerNormalization()  # Layer normalization layer

    def call(self, x, sublayer_x):
        # The sublayer input and output need to be of the same shape to be summed
        add = x + sublayer_x

        # Apply layer normalization to the sum
        return self.layer_norm(add)

# Implementing the Feed-Forward Layer
class FeedForward(Layer):
    def __init__(self, d_ff, d_model, **kwargs):
        super(FeedForward, self).__init__(**kwargs)
        self.fully_connected1 = Dense(d_ff)  # First fully connected layer
        self.fully_connected2 = Dense(d_model)  # Second fully connected layer
        self.activation = ReLU()  # ReLU activation layer

    def call(self, x):
        # The input is passed into the two fully-connected layers, with a ReLU in between
        x_fc1 = self.fully_connected1(x)

        return self.fully_connected2(self.activation(x_fc1))

# Implementing the Encoder Layer
class EncoderLayer(Layer):
    def __init__(self, h, d_k, d_v, d_model, d_ff, rate, **kwargs):
        super(EncoderLayer, self).__init__(**kwargs)
        self.multihead_attention = SIMC_MultiHeadAttention(h, d_k, d_v, d_model)
        self.dropout1 = Dropout(rate)
        self.add_norm1 = AddNormalization()
        self.feed_forward = FeedForward(d_ff, d_model)
        self.dropout2 = Dropout(rate)
        self.add_norm2 = AddNormalization()

    def call(self, x, padding_mask, training):
        # Multi-head attention layer
        multihead_output = self.multihead_attention(x, x, x, padding_mask)
        # Expected output shape = (batch_size, sequence_length, d_model)

        # Add in a dropout layer
        multihead_output = self.dropout1(multihead_output, training=training)

        # Followed by an Add & Norm layer
        addnorm_output = self.add_norm1(x, multihead_output)
        # Expected output shape = (batch_size, sequence_length, d_model)

        # Followed by a fully connected layer
        feedforward_output = self.feed_forward(addnorm_output)
        # Expected output shape = (batch_size, sequence_length, d_model)

        # Add in another dropout layer
        feedforward_output = self.dropout2(feedforward_output, training=training)

        # Followed by another Add & Norm layer
        return self.add_norm2(addnorm_output, feedforward_output)

# # Implementing the Encoder
# class Encoder(Layer):
#     def __init__(self, vocab_size, sequence_length, h, d_k, d_v, d_model, d_ff, n, rate, **kwargs):
#         super(Encoder, self).__init__(**kwargs)
#         self.pos_encoding = PositionEmbeddingFixedWeights(sequence_length, vocab_size, d_model)
#         self.dropout = Dropout(rate)
#         self.encoder_layer = [EncoderLayer(h, d_k, d_v, d_model, d_ff, rate) for _ in range(n)]

#     def call(self, input_sentence, padding_mask, training):
#         # Generate the positional encoding
#         pos_encoding_output = self.pos_encoding(input_sentence)
#         # Expected output shape = (batch_size, sequence_length, d_model)

#         # Add in a dropout layer
#         x = self.dropout(pos_encoding_output, training=training)

#         # Pass on the positional encoded values to each encoder layer
#         for i, layer in enumerate(self.encoder_layer):
#             x = layer(x, padding_mask, training)

#         return x


# Implementing the Encoder
class SIMC_Encoder(Layer):
    def __init__(self, h, d_k, d_v, d_model, d_ff, n, rate, **kwargs):
        super(SIMC_Encoder, self).__init__(**kwargs)
        self.dropout = Dropout(rate)
        self.encoder_layer = [EncoderLayer(h, d_k, d_v, d_model, d_ff, rate) for _ in range(n)]

    def call(self, inp, padding_mask, training):
        # Add in a dropout layer
        x = self.dropout(inp, training=training)

        # Pass on the positional encoded values to each encoder layer
        for i, layer in enumerate(self.encoder_layer):
            x = layer(x, padding_mask, training)

        return x

# %% [markdown]
# Some utilities for final model

# %%
from typing import List
from dataclasses import dataclass

@dataclass
class ConvolutionConfiguration:
    output_channels: List[int]
    kernel_sizes: List[int]
    paddings: List[str]

@dataclass 
class EncoderLayersConfiguration:
    h: int
    d_k: int
    d_v: int
    d_model: int
    d_ff: int
    n: int

@dataclass
class DenseConfiguration:
    sizes: List[int]

# %% [markdown]
# ### 3. Final model itself
# Model constists of a CNNn -> b EncoderLayers -> c Dense layers

# %%
def create_model_transformer(
    cnn_conf: ConvolutionConfiguration,
    enc_conf: EncoderLayersConfiguration,
    dense_conf: DenseConfiguration,
    avg_size: int = 32,
    *args,
    **kwargs
):
    if (len(args) != 0):
        print(f"!!! create_model_transformer: unused kwargs: {args}")

    if (len(kwargs) != 0):
        print(f"!!! create_model_transformer: unused kwargs: {kwargs}")

    InputLayer = keras.Input(shape=(128, 2))
    assert len(cnn_conf.output_channels) == len(cnn_conf.kernel_sizes) == len(cnn_conf.paddings)
    N_CNNs = len(cnn_conf.output_channels)
    assert N_CNNs > 0

    CNN1 = layers.Conv1D(
        cnn_conf.output_channels[0], cnn_conf.kernel_sizes[0], padding=cnn_conf.paddings[0], name="CNN1_"
    )(InputLayer)
    RELU1 = layers.ReLU(name="RELU1_")(CNN1)

    model_layers = [CNN1, RELU1]
    for i in range(1, N_CNNs):
        model_layers.append(
            layers.Conv1D(
                cnn_conf.output_channels[i],
                cnn_conf.kernel_sizes[i],
                padding=cnn_conf.paddings[i],
                name=f"CNN{i+1}_",
            )(model_layers[-1])
        )
        model_layers.append(layers.ReLU(name=f"CNN_RELU{i+1}_")(model_layers[-1]))

    enc_conf_dict = enc_conf.__dict__
    model_layers.append(SIMC_Encoder(**enc_conf_dict, rate=0.1, name="ENC1_")(RELU1, None, True))

    model_layers.append(
        layers.AveragePooling1D(avg_size, padding="same", name="AVG1_")(model_layers[-1])
    )

    model_layers.append(layers.Flatten(name="FLT1_")(model_layers[-1]))

    N_Dense = len(dense_conf.sizes)
    assert N_Dense > 0

    model_layers.append(layers.Dense(dense_conf.sizes[0], name="FC1_")(model_layers[-1]))
    model_layers.append(layers.ReLU(name="FC_RELU1_")(model_layers[-1]))

    for i in range(1, N_Dense):
        model_layers.append(layers.Dense(dense_conf.sizes[i], name=f"FC{i+1}_")(model_layers[-1]))
        model_layers.append(layers.ReLU(name=f"FC_RELU{i+1}_")(model_layers[-1]))

    model_layers.append(layers.Dense(len(modulations), name=f"FC_{N_Dense+1}_")(model_layers[-1]))
    Output = layers.Softmax()(model_layers[-1])

    model = keras.Model(inputs=[InputLayer], outputs=[Output])
    return model

# %% [markdown]
# Test code above

# %%
model = create_model_transformer(
    ConvolutionConfiguration(output_channels=[32], kernel_sizes=[8], paddings=["same"]),
    EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=4),
    DenseConfiguration(sizes=[128])
)
model.summary()
# Out:
# 2023-05-03 17:14:21.006006: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.006223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.006296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.375952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.376146: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.376225: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-03 17:14:21.376289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6056 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           544
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           50816
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax (Softmax)           (None, 11)                0
#
# =================================================================
# Total params: 69,291
# Trainable params: 69,291
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### List of models we're interested at

# %%
default_cnn_conf = ConvolutionConfiguration(
    output_channels=[32], kernel_sizes=[9], paddings=["same"]
)
default_encoder_conf = EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=4)
default_dense_conf = DenseConfiguration(sizes=[128])
default_avg_size = 32

configs = [
    [default_cnn_conf, default_encoder_conf, default_dense_conf, default_avg_size, "Default small encoder"],

    # Different kernel sizes
    # [ConvolutionConfiguration(output_channels=[32], kernel_sizes=[9], paddings=["same"]), default_encoder_conf, default_dense_conf, default_avg_size],
    [ConvolutionConfiguration(output_channels=[32], kernel_sizes=[17], paddings=["same"]), default_encoder_conf, default_dense_conf, default_avg_size, "k=17"],
    [ConvolutionConfiguration(output_channels=[32], kernel_sizes=[33], paddings=["same"]), default_encoder_conf, default_dense_conf, default_avg_size, "k=33"],
    [ConvolutionConfiguration(output_channels=[32], kernel_sizes=[65], paddings=["same"]), default_encoder_conf, default_dense_conf, default_avg_size, "k=65"],

    # Different number of encoder layers
    [default_cnn_conf, EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=2), default_dense_conf, default_avg_size, "encoder n=2"],
    # [default_cnn_conf, EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=4), default_dense_conf, default_avg_size],
    [default_cnn_conf, EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=6), default_dense_conf, default_avg_size, "encoder n=6"],
    [default_cnn_conf, EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=8), default_dense_conf, default_avg_size, "encoder n=8"],

    # Different sizes of d_model
    # [ConvolutionConfiguration(output_channels=[32], kernel_sizes=[9], paddings=["same"]),  EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=4), default_dense_conf, default_avg_size],
    [ConvolutionConfiguration(output_channels=[64], kernel_sizes=[9], paddings=["same"]),  EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=64, d_ff=128, n=4), default_dense_conf, default_avg_size, "d_model=64"],
    [ConvolutionConfiguration(output_channels=[128], kernel_sizes=[9], paddings=["same"]),  EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=128, d_ff=128, n=4), default_dense_conf, default_avg_size, "d_model=128"],
    [ConvolutionConfiguration(output_channels=[256], kernel_sizes=[9], paddings=["same"]),  EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=256, d_ff=128, n=4), default_dense_conf, default_avg_size, "d_model=256"],
]

# for config in configs:
#     print(config)
#     model = create_model_transformer(*config)
#     model.summary()

# %% [markdown]
# ### Model evaluation functions

# %%
import pickle

def evaluate_model(model, data, labels, verbose=True):
    preds = model.predict(data)
    pred_labels = np.argmax(preds, axis=1)

    cls_to_acc = {"Overall": accuracy_score(labels, pred_labels)}
    print(f"Overall test accuracy: {cls_to_acc}")
    for ci, cl in enumerate(modulations):
        class_indecies = np.where(labels == ci)[0]
        cur_true_labels = labels[class_indecies]
        cur_pred_labels = pred_labels[class_indecies]
        cls_to_acc[cl] = accuracy_score(cur_true_labels, cur_pred_labels)
        verbose and print(f"{cl} test accuracy: {cls_to_acc[cl]}")
    cm = confusion_matrix(y_true=labels, y_pred=pred_labels)
    verbose and print(cm)
    df_cm = pd.DataFrame(cm, index = modulations,
                    columns = modulations)
    if verbose:
        plt.figure(figsize = (10,7))
        sn.heatmap(df_cm, annot=True)
    return cm, cls_to_acc


def get_snrs(indecies, to_1024=False, minimum_snr=-100):
    with open(TRAIN_DATA_DIR, 'rb') as crmrn_file:
        raw_ds = pickle.load(crmrn_file, encoding="bytes")
    decoded_raw_ds = {}
    for (class_name_bytes, snr), raw_data in raw_ds.items():
        if snr < minimum_snr:
            continue
        decoded_raw_ds[(class_name_bytes.decode("utf-8"), snr)] = raw_data
    raw_ds = decoded_raw_ds

    samples_per_snr_per_modulation = raw_ds[list(raw_ds.keys())[0]].shape[0] # 1000
    snrs_sequence = [k[1] for k in raw_ds.keys()]
    result = []
    snrs = [snrs_sequence[idx // samples_per_snr_per_modulation] for idx in indecies]
    return np.array(snrs)


def get_snr_to_acc(model, data, labels, snrs, verbose=True):
    snr_to_acc = {}
    for snr in range(min(snrs), max(snrs)+2, 2):
        cur_indecies = np.where(snrs == snr)[0]
        cur_data = data[cur_indecies]
        cur_labels = labels[cur_indecies]
        cur_pred = model.predict(cur_data, verbose=0)

        cur_pred_labels = np.argmax(cur_pred, axis=1)
        verbose and print(f"snr={snr}")
        acc = accuracy_score(cur_labels, cur_pred_labels)
        verbose and print(f"Overall test accuracy: {acc}")
        snr_to_acc[snr] = acc
    return snr_to_acc

# %% [markdown]
# ### Train, evaluate, save model and evaluation results

# %%
import json

train_data = train_data.squeeze()
validation_data = validation_data.squeeze()
test_data = test_data.squeeze()

# configs = [
#     [
#         default_cnn_conf,
#         EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=2),
#         default_dense_conf,
#         default_avg_size,
#         "n=2"
#     ],
#     [
#         default_cnn_conf,
#         EncoderLayersConfiguration(h=4, d_k=32, d_v=32, d_model=32, d_ff=128, n=2),
#         default_dense_conf,
#         64,
#         "n=2, pool size=64"
#     ],
# ]

for i, config in enumerate(configs):
    model = create_model_transformer(*config)
    model.summary()

    model.compile(
        # optimizer=tf.keras.optimizers.Adam(learning_rate=0.0),
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=["accuracy"],
    )

    N_EPOCHS = 40
    # N_EPOCHS = 1
    BATCH_SIZE = 128

    h = model.fit(
        train_data,
        train_labels,
        epochs=N_EPOCHS,
        batch_size=BATCH_SIZE,
        validation_data=(validation_data, validation_labels),
        # callbacks=[lrate]
    )

    cm_val, cls_to_acc_val = evaluate_model(
        model, validation_data, validation_labels, verbose=False
    )
    snrs_val = get_snrs(validation_indecies, False)
    snr_to_acc_val = get_snr_to_acc(
        model, validation_data, validation_labels, snrs_val, verbose=False
    )

    cm_test, cls_to_acc_test = evaluate_model(model, test_data, test_labels, verbose=False)
    snr_tests = get_snrs(test_indecies, False)
    snr_to_acc_test = get_snr_to_acc(model, test_data, test_labels, snr_tests, verbose=False)

    results_dir = f"encoder_radio_ML/experiment_{i}/"
    model_configuration = {
        "cnn": config[0].__dict__,
        "encoder": config[1].__dict__,
        "dense": config[2].__dict__,
        "avg_pool": config[3],
        "description": config[4]
    }
    results = {
        "model_configuration": model_configuration,
        "train_history": h.history,
        "cm_val": cm_val.tolist(),
        "cls_to_acc_val": cls_to_acc_val,
        "snr_to_acc_val": snr_to_acc_val,
        "cm_test": cm_test.tolist(),
        "cls_to_acc_test": cls_to_acc_test,
        "snr_to_acc_test": snr_to_acc_test,
    }

    os.makedirs(results_dir, exist_ok=True)
    with open(results_dir + "results.json", "w") as res_file:
        json.dump(results, res_file, indent=4)
    model.save(results_dir + "model")
# Out:
# !!! create_model_transformer: unused kwargs: ('Default small encoder',)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           608
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           50816
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_1 (Softmax)         (None, 11)                0
#
# =================================================================
# Total params: 69,355
# Trainable params: 69,355
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 2023-05-03 17:14:34.771779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-03 17:14:35.258589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-03 17:14:35.310016: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f4698e92c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-03 17:14:35.310042: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti Laptop GPU, Compute Capability 8.6
# 2023-05-03 17:14:35.312842: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-03 17:14:35.396615: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1375/1375 [==============================] - 45s 27ms/step - loss: 1.7204 - accuracy: 0.3444 - val_loss: 1.3812 - val_accuracy: 0.4542
# Epoch 2/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.3516 - accuracy: 0.4726 - val_loss: 1.3035 - val_accuracy: 0.4931
# Epoch 3/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.2883 - accuracy: 0.5049 - val_loss: 1.2374 - val_accuracy: 0.5264
# Epoch 4/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.2426 - accuracy: 0.5257 - val_loss: 1.2051 - val_accuracy: 0.5420
# Epoch 5/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.2151 - accuracy: 0.5385 - val_loss: 1.2143 - val_accuracy: 0.5394
# Epoch 6/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1930 - accuracy: 0.5482 - val_loss: 1.2072 - val_accuracy: 0.5477
# Epoch 7/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1767 - accuracy: 0.5548 - val_loss: 1.1686 - val_accuracy: 0.5520
# Epoch 8/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1630 - accuracy: 0.5620 - val_loss: 1.1972 - val_accuracy: 0.5525
# Epoch 9/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1532 - accuracy: 0.5664 - val_loss: 1.1813 - val_accuracy: 0.5538
# Epoch 10/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1468 - accuracy: 0.5716 - val_loss: 1.1388 - val_accuracy: 0.5762
# Epoch 11/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1360 - accuracy: 0.5754 - val_loss: 1.1397 - val_accuracy: 0.5747
# Epoch 12/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.1292 - accuracy: 0.5794 - val_loss: 1.1287 - val_accuracy: 0.5834
# Epoch 13/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1197 - accuracy: 0.5845 - val_loss: 1.1099 - val_accuracy: 0.5933
# Epoch 14/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.1139 - accuracy: 0.5878 - val_loss: 1.1169 - val_accuracy: 0.5872
# Epoch 15/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1092 - accuracy: 0.5892 - val_loss: 1.1323 - val_accuracy: 0.5783
# Epoch 16/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1050 - accuracy: 0.5913 - val_loss: 1.1050 - val_accuracy: 0.5936
# Epoch 17/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1006 - accuracy: 0.5936 - val_loss: 1.1088 - val_accuracy: 0.5934
# Epoch 18/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0979 - accuracy: 0.5945 - val_loss: 1.1046 - val_accuracy: 0.5941
# Epoch 19/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0938 - accuracy: 0.5971 - val_loss: 1.0931 - val_accuracy: 0.5997
# Epoch 20/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0915 - accuracy: 0.5981 - val_loss: 1.1024 - val_accuracy: 0.5989
# Epoch 21/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0885 - accuracy: 0.5998 - val_loss: 1.1085 - val_accuracy: 0.5919
# Epoch 22/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0852 - accuracy: 0.6008 - val_loss: 1.0992 - val_accuracy: 0.5976
# Epoch 23/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0819 - accuracy: 0.6027 - val_loss: 1.1014 - val_accuracy: 0.5968
# Epoch 24/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0809 - accuracy: 0.6030 - val_loss: 1.0962 - val_accuracy: 0.5986
# Epoch 25/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0783 - accuracy: 0.6043 - val_loss: 1.0904 - val_accuracy: 0.5990
# Epoch 26/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0761 - accuracy: 0.6046 - val_loss: 1.1027 - val_accuracy: 0.5963
# Epoch 27/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0755 - accuracy: 0.6051 - val_loss: 1.1291 - val_accuracy: 0.5827
# Epoch 28/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0713 - accuracy: 0.6067 - val_loss: 1.0895 - val_accuracy: 0.6027
# Epoch 29/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0711 - accuracy: 0.6073 - val_loss: 1.0939 - val_accuracy: 0.6029
# Epoch 30/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0685 - accuracy: 0.6086 - val_loss: 1.0952 - val_accuracy: 0.6025
# Epoch 31/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0666 - accuracy: 0.6100 - val_loss: 1.0989 - val_accuracy: 0.6000
# Epoch 32/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0637 - accuracy: 0.6105 - val_loss: 1.0786 - val_accuracy: 0.6018
# Epoch 33/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0627 - accuracy: 0.6120 - val_loss: 1.0864 - val_accuracy: 0.6034
# Epoch 34/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0611 - accuracy: 0.6126 - val_loss: 1.0801 - val_accuracy: 0.6050
# Epoch 35/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0583 - accuracy: 0.6131 - val_loss: 1.0811 - val_accuracy: 0.6060
# Epoch 36/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0589 - accuracy: 0.6125 - val_loss: 1.0775 - val_accuracy: 0.6082
# Epoch 37/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0563 - accuracy: 0.6146 - val_loss: 1.1000 - val_accuracy: 0.5967
# Epoch 38/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0546 - accuracy: 0.6142 - val_loss: 1.0850 - val_accuracy: 0.6060
# Epoch 39/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0532 - accuracy: 0.6148 - val_loss: 1.0823 - val_accuracy: 0.6063
# Epoch 40/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0533 - accuracy: 0.6152 - val_loss: 1.0773 - val_accuracy: 0.6093
# 688/688 [==============================] - 7s 10ms/step
# Overall test accuracy: {'Overall': 0.6089545454545454}
# 688/688 [==============================] - 7s 10ms/step
# Overall test accuracy: {'Overall': 0.605909090909091}
# 2023-05-03 17:40:38.221342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 17:40:38.253617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 17:40:39.663486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 17:40:39.694066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_9_layer_call_fn, dropout_9_layer_call_and_return_conditional_losses, encoder_layer_4_layer_call_fn, encoder_layer_4_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_0/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_0/model/assets
# !!! create_model_transformer: unused kwargs: ('k=17',)
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           1120
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           50816
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_2 (Softmax)         (None, 11)                0
#
# =================================================================
# Total params: 69,867
# Trainable params: 69,867
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1375/1375 [==============================] - 46s 28ms/step - loss: 1.7250 - accuracy: 0.3463 - val_loss: 1.3459 - val_accuracy: 0.4673
# Epoch 2/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.2938 - accuracy: 0.4935 - val_loss: 1.2618 - val_accuracy: 0.5114
# Epoch 3/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.2382 - accuracy: 0.5185 - val_loss: 1.2248 - val_accuracy: 0.5284
# Epoch 4/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.2053 - accuracy: 0.5357 - val_loss: 1.1916 - val_accuracy: 0.5431
# Epoch 5/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1799 - accuracy: 0.5477 - val_loss: 1.1670 - val_accuracy: 0.5537
# Epoch 6/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1595 - accuracy: 0.5555 - val_loss: 1.1621 - val_accuracy: 0.5555
# Epoch 7/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1499 - accuracy: 0.5600 - val_loss: 1.1472 - val_accuracy: 0.5570
# Epoch 8/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1403 - accuracy: 0.5643 - val_loss: 1.1441 - val_accuracy: 0.5647
# Epoch 9/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.1318 - accuracy: 0.5681 - val_loss: 1.1273 - val_accuracy: 0.5683
# Epoch 10/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1265 - accuracy: 0.5697 - val_loss: 1.1297 - val_accuracy: 0.5663
# Epoch 11/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1220 - accuracy: 0.5741 - val_loss: 1.1312 - val_accuracy: 0.5730
# Epoch 12/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.1141 - accuracy: 0.5785 - val_loss: 1.1366 - val_accuracy: 0.5688
# Epoch 13/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1119 - accuracy: 0.5799 - val_loss: 1.1103 - val_accuracy: 0.5814
# Epoch 14/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1066 - accuracy: 0.5848 - val_loss: 1.1255 - val_accuracy: 0.5802
# Epoch 15/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1026 - accuracy: 0.5874 - val_loss: 1.1084 - val_accuracy: 0.5852
# Epoch 16/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0978 - accuracy: 0.5902 - val_loss: 1.0993 - val_accuracy: 0.5925
# Epoch 17/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0942 - accuracy: 0.5920 - val_loss: 1.0941 - val_accuracy: 0.5920
# Epoch 18/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0910 - accuracy: 0.5935 - val_loss: 1.1071 - val_accuracy: 0.5905
# Epoch 19/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0867 - accuracy: 0.5961 - val_loss: 1.0901 - val_accuracy: 0.5980
# Epoch 20/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0865 - accuracy: 0.5969 - val_loss: 1.0899 - val_accuracy: 0.6001
# Epoch 21/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0820 - accuracy: 0.5989 - val_loss: 1.1159 - val_accuracy: 0.5885
# Epoch 22/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0799 - accuracy: 0.6004 - val_loss: 1.1068 - val_accuracy: 0.5915
# Epoch 23/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0742 - accuracy: 0.6038 - val_loss: 1.0914 - val_accuracy: 0.6019
# Epoch 24/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0735 - accuracy: 0.6054 - val_loss: 1.0833 - val_accuracy: 0.6035
# Epoch 25/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0712 - accuracy: 0.6056 - val_loss: 1.0840 - val_accuracy: 0.6045
# Epoch 26/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0691 - accuracy: 0.6071 - val_loss: 1.0918 - val_accuracy: 0.6020
# Epoch 27/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0684 - accuracy: 0.6077 - val_loss: 1.1114 - val_accuracy: 0.5905
# Epoch 28/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0652 - accuracy: 0.6093 - val_loss: 1.1054 - val_accuracy: 0.5959
# Epoch 29/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0642 - accuracy: 0.6094 - val_loss: 1.0767 - val_accuracy: 0.6054
# Epoch 30/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0602 - accuracy: 0.6115 - val_loss: 1.0792 - val_accuracy: 0.6055
# Epoch 31/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0591 - accuracy: 0.6119 - val_loss: 1.0849 - val_accuracy: 0.6017
# Epoch 32/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0574 - accuracy: 0.6125 - val_loss: 1.0729 - val_accuracy: 0.6057
# Epoch 33/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0565 - accuracy: 0.6135 - val_loss: 1.0794 - val_accuracy: 0.6077
# Epoch 34/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0533 - accuracy: 0.6141 - val_loss: 1.0757 - val_accuracy: 0.6069
# Epoch 35/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0525 - accuracy: 0.6155 - val_loss: 1.0695 - val_accuracy: 0.6080
# Epoch 36/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0512 - accuracy: 0.6159 - val_loss: 1.0805 - val_accuracy: 0.6054
# Epoch 37/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0495 - accuracy: 0.6168 - val_loss: 1.0781 - val_accuracy: 0.6094
# Epoch 38/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0481 - accuracy: 0.6177 - val_loss: 1.0738 - val_accuracy: 0.6097
# Epoch 39/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0476 - accuracy: 0.6167 - val_loss: 1.0696 - val_accuracy: 0.6126
# Epoch 40/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0463 - accuracy: 0.6185 - val_loss: 1.0790 - val_accuracy: 0.6092
# 688/688 [==============================] - 7s 9ms/step
# Overall test accuracy: {'Overall': 0.6081363636363636}
# 688/688 [==============================] - 6s 9ms/step
# Overall test accuracy: {'Overall': 0.606909090909091}
# 2023-05-03 18:06:55.683619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:06:55.718826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:06:57.061019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:06:57.094507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_18_layer_call_fn, dropout_18_layer_call_and_return_conditional_losses, encoder_layer_8_layer_call_fn, encoder_layer_8_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_1/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_1/model/assets
# !!! create_model_transformer: unused kwargs: ('k=33',)
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           2144
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           50816
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_3 (Softmax)         (None, 11)                0
#
# =================================================================
# Total params: 70,891
# Trainable params: 70,891
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1375/1375 [==============================] - 46s 28ms/step - loss: 1.7176 - accuracy: 0.3376 - val_loss: 1.3701 - val_accuracy: 0.4603
# Epoch 2/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.3021 - accuracy: 0.4909 - val_loss: 1.2432 - val_accuracy: 0.5061
# Epoch 3/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.2391 - accuracy: 0.5168 - val_loss: 1.2325 - val_accuracy: 0.5226
# Epoch 4/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.2088 - accuracy: 0.5327 - val_loss: 1.2126 - val_accuracy: 0.5366
# Epoch 5/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1804 - accuracy: 0.5470 - val_loss: 1.1597 - val_accuracy: 0.5538
# Epoch 6/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1609 - accuracy: 0.5559 - val_loss: 1.1551 - val_accuracy: 0.5575
# Epoch 7/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1483 - accuracy: 0.5609 - val_loss: 1.1490 - val_accuracy: 0.5606
# Epoch 8/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1401 - accuracy: 0.5646 - val_loss: 1.1401 - val_accuracy: 0.5607
# Epoch 9/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1347 - accuracy: 0.5669 - val_loss: 1.1485 - val_accuracy: 0.5630
# Epoch 10/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1276 - accuracy: 0.5692 - val_loss: 1.1361 - val_accuracy: 0.5656
# Epoch 11/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1214 - accuracy: 0.5734 - val_loss: 1.1245 - val_accuracy: 0.5745
# Epoch 12/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1132 - accuracy: 0.5767 - val_loss: 1.1274 - val_accuracy: 0.5682
# Epoch 13/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1089 - accuracy: 0.5803 - val_loss: 1.1082 - val_accuracy: 0.5866
# Epoch 14/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1030 - accuracy: 0.5852 - val_loss: 1.1169 - val_accuracy: 0.5862
# Epoch 15/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0975 - accuracy: 0.5881 - val_loss: 1.1078 - val_accuracy: 0.5838
# Epoch 16/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0935 - accuracy: 0.5919 - val_loss: 1.0979 - val_accuracy: 0.5929
# Epoch 17/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0891 - accuracy: 0.5941 - val_loss: 1.1023 - val_accuracy: 0.5952
# Epoch 18/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0856 - accuracy: 0.5974 - val_loss: 1.0946 - val_accuracy: 0.5977
# Epoch 19/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0814 - accuracy: 0.5997 - val_loss: 1.0881 - val_accuracy: 0.5989
# Epoch 20/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0775 - accuracy: 0.6024 - val_loss: 1.0930 - val_accuracy: 0.6009
# Epoch 21/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0745 - accuracy: 0.6037 - val_loss: 1.0850 - val_accuracy: 0.6020
# Epoch 22/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0690 - accuracy: 0.6062 - val_loss: 1.0876 - val_accuracy: 0.6030
# Epoch 23/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0659 - accuracy: 0.6076 - val_loss: 1.0914 - val_accuracy: 0.6030
# Epoch 24/40
# 1375/1375 [==============================] - 39s 28ms/step - loss: 1.0640 - accuracy: 0.6093 - val_loss: 1.0769 - val_accuracy: 0.6035
# Epoch 25/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0620 - accuracy: 0.6106 - val_loss: 1.0775 - val_accuracy: 0.6046
# Epoch 26/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0606 - accuracy: 0.6109 - val_loss: 1.0854 - val_accuracy: 0.6038
# Epoch 27/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0573 - accuracy: 0.6125 - val_loss: 1.0999 - val_accuracy: 0.5932
# Epoch 28/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0550 - accuracy: 0.6134 - val_loss: 1.0798 - val_accuracy: 0.6054
# Epoch 29/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0535 - accuracy: 0.6150 - val_loss: 1.0705 - val_accuracy: 0.6112
# Epoch 30/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0516 - accuracy: 0.6153 - val_loss: 1.0731 - val_accuracy: 0.6110
# Epoch 31/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0513 - accuracy: 0.6158 - val_loss: 1.0797 - val_accuracy: 0.6074
# Epoch 32/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0468 - accuracy: 0.6177 - val_loss: 1.0670 - val_accuracy: 0.6111
# Epoch 33/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0477 - accuracy: 0.6175 - val_loss: 1.0891 - val_accuracy: 0.6057
# Epoch 34/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0460 - accuracy: 0.6181 - val_loss: 1.0684 - val_accuracy: 0.6102
# Epoch 35/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0425 - accuracy: 0.6193 - val_loss: 1.0742 - val_accuracy: 0.6125
# Epoch 36/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0427 - accuracy: 0.6197 - val_loss: 1.0766 - val_accuracy: 0.6113
# Epoch 37/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0416 - accuracy: 0.6204 - val_loss: 1.0681 - val_accuracy: 0.6143
# Epoch 38/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0381 - accuracy: 0.6210 - val_loss: 1.0765 - val_accuracy: 0.6086
# Epoch 39/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0393 - accuracy: 0.6210 - val_loss: 1.0663 - val_accuracy: 0.6146
# Epoch 40/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0358 - accuracy: 0.6223 - val_loss: 1.0691 - val_accuracy: 0.6145
# 688/688 [==============================] - 7s 9ms/step
# Overall test accuracy: {'Overall': 0.6142727272727273}
# 688/688 [==============================] - 6s 9ms/step
# Overall test accuracy: {'Overall': 0.6131818181818182}
# 2023-05-03 18:33:09.484271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:33:09.513097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:33:10.637767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:33:10.665476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_27_layer_call_fn, dropout_27_layer_call_and_return_conditional_losses, encoder_layer_12_layer_call_fn, encoder_layer_12_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_2/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_2/model/assets
# !!! create_model_transformer: unused kwargs: ('k=65',)
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           4192
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           50816
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_4 (Softmax)         (None, 11)                0
#
# =================================================================
# Total params: 72,939
# Trainable params: 72,939
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1375/1375 [==============================] - 45s 28ms/step - loss: 1.7002 - accuracy: 0.3467 - val_loss: 1.3991 - val_accuracy: 0.4526
# Epoch 2/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.2890 - accuracy: 0.5001 - val_loss: 1.2377 - val_accuracy: 0.5220
# Epoch 3/40
# 1375/1375 [==============================] - 38s 27ms/step - loss: 1.2228 - accuracy: 0.5289 - val_loss: 1.2180 - val_accuracy: 0.5335
# Epoch 4/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1928 - accuracy: 0.5422 - val_loss: 1.1873 - val_accuracy: 0.5467
# Epoch 5/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1710 - accuracy: 0.5522 - val_loss: 1.1551 - val_accuracy: 0.5560
# Epoch 6/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1546 - accuracy: 0.5593 - val_loss: 1.1460 - val_accuracy: 0.5640
# Epoch 7/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1471 - accuracy: 0.5618 - val_loss: 1.1502 - val_accuracy: 0.5589
# Epoch 8/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1394 - accuracy: 0.5653 - val_loss: 1.1627 - val_accuracy: 0.5587
# Epoch 9/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1335 - accuracy: 0.5681 - val_loss: 1.1338 - val_accuracy: 0.5645
# Epoch 10/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1324 - accuracy: 0.5671 - val_loss: 1.1335 - val_accuracy: 0.5681
# Epoch 11/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1238 - accuracy: 0.5722 - val_loss: 1.1293 - val_accuracy: 0.5700
# Epoch 12/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.1193 - accuracy: 0.5747 - val_loss: 1.1320 - val_accuracy: 0.5723
# Epoch 13/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1152 - accuracy: 0.5779 - val_loss: 1.1190 - val_accuracy: 0.5779
# Epoch 14/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1096 - accuracy: 0.5808 - val_loss: 1.1187 - val_accuracy: 0.5755
# Epoch 15/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1076 - accuracy: 0.5836 - val_loss: 1.1153 - val_accuracy: 0.5806
# Epoch 16/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.1027 - accuracy: 0.5860 - val_loss: 1.0998 - val_accuracy: 0.5888
# Epoch 17/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0985 - accuracy: 0.5895 - val_loss: 1.0939 - val_accuracy: 0.5910
# Epoch 18/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0925 - accuracy: 0.5941 - val_loss: 1.1056 - val_accuracy: 0.5911
# Epoch 19/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.0903 - accuracy: 0.5952 - val_loss: 1.0912 - val_accuracy: 0.5956
# Epoch 20/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0853 - accuracy: 0.5981 - val_loss: 1.0832 - val_accuracy: 0.6005
# Epoch 21/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0832 - accuracy: 0.5991 - val_loss: 1.1185 - val_accuracy: 0.5885
# Epoch 22/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0776 - accuracy: 0.6018 - val_loss: 1.1142 - val_accuracy: 0.5899
# Epoch 23/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0744 - accuracy: 0.6040 - val_loss: 1.0836 - val_accuracy: 0.6040
# Epoch 24/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0721 - accuracy: 0.6057 - val_loss: 1.0769 - val_accuracy: 0.6054
# Epoch 25/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0698 - accuracy: 0.6068 - val_loss: 1.0737 - val_accuracy: 0.6062
# Epoch 26/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0648 - accuracy: 0.6091 - val_loss: 1.0739 - val_accuracy: 0.6069
# Epoch 27/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0648 - accuracy: 0.6099 - val_loss: 1.0860 - val_accuracy: 0.6004
# Epoch 28/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0611 - accuracy: 0.6101 - val_loss: 1.0830 - val_accuracy: 0.6047
# Epoch 29/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0593 - accuracy: 0.6121 - val_loss: 1.0740 - val_accuracy: 0.6084
# Epoch 30/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0569 - accuracy: 0.6124 - val_loss: 1.0757 - val_accuracy: 0.6084
# Epoch 31/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0543 - accuracy: 0.6150 - val_loss: 1.0807 - val_accuracy: 0.6046
# Epoch 32/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0520 - accuracy: 0.6152 - val_loss: 1.0718 - val_accuracy: 0.6056
# Epoch 33/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0519 - accuracy: 0.6157 - val_loss: 1.0936 - val_accuracy: 0.6026
# Epoch 34/40
# 1375/1375 [==============================] - 37s 27ms/step - loss: 1.0495 - accuracy: 0.6166 - val_loss: 1.0888 - val_accuracy: 0.5992
# Epoch 35/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0487 - accuracy: 0.6167 - val_loss: 1.0604 - val_accuracy: 0.6140
# Epoch 36/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0465 - accuracy: 0.6173 - val_loss: 1.0761 - val_accuracy: 0.6107
# Epoch 37/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0464 - accuracy: 0.6179 - val_loss: 1.0715 - val_accuracy: 0.6106
# Epoch 38/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0436 - accuracy: 0.6189 - val_loss: 1.0952 - val_accuracy: 0.6030
# Epoch 39/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0422 - accuracy: 0.6197 - val_loss: 1.0699 - val_accuracy: 0.6114
# Epoch 40/40
# 1375/1375 [==============================] - 38s 28ms/step - loss: 1.0407 - accuracy: 0.6205 - val_loss: 1.0655 - val_accuracy: 0.6145
# 688/688 [==============================] - 7s 9ms/step
# Overall test accuracy: {'Overall': 0.6118181818181818}
# 688/688 [==============================] - 7s 10ms/step
# Overall test accuracy: {'Overall': 0.6123181818181819}
# 2023-05-03 18:59:13.747503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:59:13.778608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:59:14.889773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# 2023-05-03 18:59:14.916525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_36_layer_call_fn, dropout_36_layer_call_and_return_conditional_losses, encoder_layer_16_layer_call_fn, encoder_layer_16_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_3/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_3/model/assets
# !!! create_model_transformer: unused kwargs: ('encoder n=2',)
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 32)           608
#
#  RELU1_ (ReLU)               (None, 128, 32)           0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 32)           25408
#
#  AVG1_ (AveragePooling1D)    (None, 4, 32)             0
#
#  FLT1_ (Flatten)             (None, 128)               0
#
#  FC1_ (Dense)                (None, 128)               16512
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_5 (Softmax)         (None, 11)                0
#
# =================================================================
# Total params: 43,947
# Trainable params: 43,947
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1375/1375 [==============================] - 24s 15ms/step - loss: 1.7242 - accuracy: 0.3480 - val_loss: 1.3542 - val_accuracy: 0.4703
# Epoch 2/40
# 1375/1375 [==============================] - 20s 14ms/step - loss: 1.3130 - accuracy: 0.4884 - val_loss: 1.2657 - val_accuracy: 0.5095
# Epoch 3/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.2545 - accuracy: 0.5126 - val_loss: 1.2531 - val_accuracy: 0.5161
# Epoch 4/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.2132 - accuracy: 0.5331 - val_loss: 1.2024 - val_accuracy: 0.5363
# Epoch 5/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1866 - accuracy: 0.5441 - val_loss: 1.1693 - val_accuracy: 0.5501
# Epoch 6/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1689 - accuracy: 0.5529 - val_loss: 1.1933 - val_accuracy: 0.5443
# Epoch 7/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1591 - accuracy: 0.5574 - val_loss: 1.1611 - val_accuracy: 0.5529
# Epoch 8/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1500 - accuracy: 0.5601 - val_loss: 1.1718 - val_accuracy: 0.5541
# Epoch 9/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1437 - accuracy: 0.5630 - val_loss: 1.1542 - val_accuracy: 0.5598
# Epoch 10/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1400 - accuracy: 0.5660 - val_loss: 1.1443 - val_accuracy: 0.5653
# Epoch 11/40
# 1375/1375 [==============================] - 20s 14ms/step - loss: 1.1320 - accuracy: 0.5717 - val_loss: 1.1395 - val_accuracy: 0.5741
# Epoch 12/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1259 - accuracy: 0.5763 - val_loss: 1.1482 - val_accuracy: 0.5665
# Epoch 13/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1225 - accuracy: 0.5774 - val_loss: 1.1173 - val_accuracy: 0.5822
# Epoch 14/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1160 - accuracy: 0.5825 - val_loss: 1.1240 - val_accuracy: 0.5812
# Epoch 15/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1121 - accuracy: 0.5839 - val_loss: 1.1427 - val_accuracy: 0.5715
# Epoch 16/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1098 - accuracy: 0.5859 - val_loss: 1.1088 - val_accuracy: 0.5885
# Epoch 17/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1063 - accuracy: 0.5881 - val_loss: 1.1234 - val_accuracy: 0.5806
# Epoch 18/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.1034 - accuracy: 0.5891 - val_loss: 1.1243 - val_accuracy: 0.5835
# Epoch 19/40
# 1375/1375 [==============================] - 20s 14ms/step - loss: 1.0991 - accuracy: 0.5912 - val_loss: 1.1103 - val_accuracy: 0.5899
# Epoch 20/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0976 - accuracy: 0.5925 - val_loss: 1.1128 - val_accuracy: 0.5885
# Epoch 21/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0952 - accuracy: 0.5934 - val_loss: 1.1202 - val_accuracy: 0.5835
# Epoch 22/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0918 - accuracy: 0.5960 - val_loss: 1.1138 - val_accuracy: 0.5870
# Epoch 23/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0899 - accuracy: 0.5961 - val_loss: 1.1046 - val_accuracy: 0.5903
# Epoch 24/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0893 - accuracy: 0.5956 - val_loss: 1.1091 - val_accuracy: 0.5898
# Epoch 25/40
# 1375/1375 [==============================] - 20s 14ms/step - loss: 1.0870 - accuracy: 0.5980 - val_loss: 1.1191 - val_accuracy: 0.5893
# Epoch 26/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0851 - accuracy: 0.5989 - val_loss: 1.1085 - val_accuracy: 0.5938
# Epoch 27/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0845 - accuracy: 0.5994 - val_loss: 1.1185 - val_accuracy: 0.5879
# Epoch 28/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0814 - accuracy: 0.6000 - val_loss: 1.0954 - val_accuracy: 0.5976
# Epoch 29/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0801 - accuracy: 0.6009 - val_loss: 1.1101 - val_accuracy: 0.5920
# Epoch 30/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0764 - accuracy: 0.6033 - val_loss: 1.0969 - val_accuracy: 0.5958
# Epoch 31/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0747 - accuracy: 0.6043 - val_loss: 1.1015 - val_accuracy: 0.5937
# Epoch 32/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0739 - accuracy: 0.6042 - val_loss: 1.0901 - val_accuracy: 0.5971
# Epoch 33/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0726 - accuracy: 0.6048 - val_loss: 1.1038 - val_accuracy: 0.5939
# Epoch 34/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0709 - accuracy: 0.6055 - val_loss: 1.0971 - val_accuracy: 0.5975
# Epoch 35/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0699 - accuracy: 0.6059 - val_loss: 1.0977 - val_accuracy: 0.5966
# Epoch 36/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0695 - accuracy: 0.6059 - val_loss: 1.1029 - val_accuracy: 0.5935
# Epoch 37/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0678 - accuracy: 0.6062 - val_loss: 1.1034 - val_accuracy: 0.5958
# Epoch 38/40
# 1375/1375 [==============================] - 20s 15ms/step - loss: 1.0665 - accuracy: 0.6079 - val_loss: 1.1014 - val_accuracy: 0.5950
# Epoch 39/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0650 - accuracy: 0.6080 - val_loss: 1.0865 - val_accuracy: 0.6016
# Epoch 40/40
# 1375/1375 [==============================] - 21s 15ms/step - loss: 1.0639 - accuracy: 0.6100 - val_loss: 1.0896 - val_accuracy: 0.6027
# 688/688 [==============================] - 4s 5ms/step
# Overall test accuracy: {'Overall': 0.6027272727272728}
# 688/688 [==============================] - 4s 5ms/step
# Overall test accuracy: {'Overall': 0.5996363636363636}
# 2023-05-03 19:13:11.655448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,32]
# 	 [[{{node inp}}]]
# ...
# Epoch 12/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.1167 - accuracy: 0.5875 - val_loss: 1.1464 - val_accuracy: 0.5788
# Epoch 13/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.1105 - accuracy: 0.5903 - val_loss: 1.1048 - val_accuracy: 0.5940
# Epoch 14/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.1070 - accuracy: 0.5920 - val_loss: 1.1149 - val_accuracy: 0.5892
# Epoch 15/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.1031 - accuracy: 0.5944 - val_loss: 1.1259 - val_accuracy: 0.5828
# Epoch 16/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.1021 - accuracy: 0.5947 - val_loss: 1.0946 - val_accuracy: 0.5994
# Epoch 17/40
# 1375/1375 [==============================] - 53s 38ms/step - loss: 1.0965 - accuracy: 0.5964 - val_loss: 1.0964 - val_accuracy: 0.5972
# Epoch 18/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0945 - accuracy: 0.5972 - val_loss: 1.1117 - val_accuracy: 0.5937
# Epoch 19/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0915 - accuracy: 0.5998 - val_loss: 1.0972 - val_accuracy: 0.5980
# Epoch 20/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0898 - accuracy: 0.6003 - val_loss: 1.0889 - val_accuracy: 0.6026
# Epoch 21/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0872 - accuracy: 0.6016 - val_loss: 1.1020 - val_accuracy: 0.5974
# Epoch 22/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0831 - accuracy: 0.6032 - val_loss: 1.1074 - val_accuracy: 0.5925
# Epoch 23/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0807 - accuracy: 0.6039 - val_loss: 1.1003 - val_accuracy: 0.5982
# Epoch 24/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0798 - accuracy: 0.6052 - val_loss: 1.0905 - val_accuracy: 0.6015
# Epoch 25/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0767 - accuracy: 0.6059 - val_loss: 1.0881 - val_accuracy: 0.6012
# Epoch 26/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0747 - accuracy: 0.6052 - val_loss: 1.1021 - val_accuracy: 0.6000
# Epoch 27/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0734 - accuracy: 0.6084 - val_loss: 1.1530 - val_accuracy: 0.5718
# Epoch 28/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0700 - accuracy: 0.6089 - val_loss: 1.0956 - val_accuracy: 0.5994
# Epoch 29/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0685 - accuracy: 0.6098 - val_loss: 1.0857 - val_accuracy: 0.6053
# Epoch 30/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0650 - accuracy: 0.6114 - val_loss: 1.0831 - val_accuracy: 0.6059
# Epoch 31/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0643 - accuracy: 0.6114 - val_loss: 1.0919 - val_accuracy: 0.6014
# Epoch 32/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0609 - accuracy: 0.6131 - val_loss: 1.0834 - val_accuracy: 0.6022
# Epoch 33/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0599 - accuracy: 0.6135 - val_loss: 1.0944 - val_accuracy: 0.6034
# Epoch 34/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0588 - accuracy: 0.6142 - val_loss: 1.0832 - val_accuracy: 0.6025
# Epoch 35/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0559 - accuracy: 0.6154 - val_loss: 1.0768 - val_accuracy: 0.6083
# Epoch 36/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0529 - accuracy: 0.6165 - val_loss: 1.0795 - val_accuracy: 0.6062
# Epoch 37/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0536 - accuracy: 0.6165 - val_loss: 1.0912 - val_accuracy: 0.6027
# Epoch 38/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0499 - accuracy: 0.6170 - val_loss: 1.1010 - val_accuracy: 0.5996
# Epoch 39/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0482 - accuracy: 0.6182 - val_loss: 1.0718 - val_accuracy: 0.6116
# Epoch 40/40
# 1375/1375 [==============================] - 52s 38ms/step - loss: 1.0479 - accuracy: 0.6191 - val_loss: 1.0754 - val_accuracy: 0.6096
# 688/688 [==============================] - 7s 9ms/step
# Overall test accuracy: {'Overall': 0.6107272727272727}
# 688/688 [==============================] - 7s 10ms/step
# Overall test accuracy: {'Overall': 0.6108181818181818}
# 2023-05-03 21:46:28.905498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,128]
# 	 [[{{node inp}}]]
# 2023-05-03 21:46:28.936040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,128]
# 	 [[{{node inp}}]]
# 2023-05-03 21:46:30.471548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,128]
# 	 [[{{node inp}}]]
# 2023-05-03 21:46:30.512544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,128]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_89_layer_call_fn, dropout_89_layer_call_and_return_conditional_losses, encoder_layer_40_layer_call_fn, encoder_layer_40_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_8/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_8/model/assets
# !!! create_model_transformer: unused kwargs: ('d_model=256',)
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 128, 2)]          0
#
#  CNN1_ (Conv1D)              (None, 128, 256)          4864
#
#  RELU1_ (ReLU)               (None, 128, 256)          0
#
#  ENC1_ (SIMC_Encoder)        (None, 128, 256)          400256
#
#  AVG1_ (AveragePooling1D)    (None, 4, 256)            0
#
#  FLT1_ (Flatten)             (None, 1024)              0
#
#  FC1_ (Dense)                (None, 128)               131200
#
#  FC_RELU1_ (ReLU)            (None, 128)               0
#
#  FC_2_ (Dense)               (None, 11)                1419
#
#  softmax_10 (Softmax)        (None, 11)                0
#
# =================================================================
# Total params: 537,739
# Trainable params: 537,739
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1375/1375 [==============================] - 75s 49ms/step - loss: 2.4061 - accuracy: 0.0916 - val_loss: 2.3978 - val_accuracy: 0.0936
# Epoch 2/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0900 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 3/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0891 - val_loss: 2.3979 - val_accuracy: 0.0919
# Epoch 4/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0896 - val_loss: 2.3980 - val_accuracy: 0.0896
# Epoch 5/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0899 - val_loss: 2.3979 - val_accuracy: 0.0896
# Epoch 6/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0909 - val_loss: 2.3980 - val_accuracy: 0.0895
# Epoch 7/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0906 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 8/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0899 - val_loss: 2.3981 - val_accuracy: 0.0903
# Epoch 9/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0902 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 10/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0893 - val_loss: 2.3980 - val_accuracy: 0.0903
# Epoch 11/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0909 - val_loss: 2.3981 - val_accuracy: 0.0896
# Epoch 12/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0910 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 13/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0908 - val_loss: 2.3981 - val_accuracy: 0.0896
# Epoch 14/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0915 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 15/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0905 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 16/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0901 - val_loss: 2.3979 - val_accuracy: 0.0896
# Epoch 17/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0902 - val_loss: 2.3980 - val_accuracy: 0.0902
# Epoch 18/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0908 - val_loss: 2.3979 - val_accuracy: 0.0902
# Epoch 19/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0887 - val_loss: 2.3979 - val_accuracy: 0.0903
# Epoch 20/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0908 - val_loss: 2.3980 - val_accuracy: 0.0914
# Epoch 21/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0908 - val_loss: 2.3980 - val_accuracy: 0.0918
# Epoch 22/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0898 - val_loss: 2.3979 - val_accuracy: 0.0895
# Epoch 23/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0900 - val_loss: 2.3979 - val_accuracy: 0.0920
# Epoch 24/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0900 - val_loss: 2.3979 - val_accuracy: 0.0920
# Epoch 25/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0903 - val_loss: 2.3979 - val_accuracy: 0.0936
# Epoch 26/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0895 - val_loss: 2.3979 - val_accuracy: 0.0919
# Epoch 27/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0904 - val_loss: 2.3979 - val_accuracy: 0.0896
# Epoch 28/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0908 - val_loss: 2.3980 - val_accuracy: 0.0903
# Epoch 29/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0905 - val_loss: 2.3980 - val_accuracy: 0.0903
# Epoch 30/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0904 - val_loss: 2.3979 - val_accuracy: 0.0919
# Epoch 31/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0894 - val_loss: 2.3980 - val_accuracy: 0.0896
# Epoch 32/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0888 - val_loss: 2.3979 - val_accuracy: 0.0902
# Epoch 33/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0911 - val_loss: 2.3979 - val_accuracy: 0.0902
# Epoch 34/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0892 - val_loss: 2.3979 - val_accuracy: 0.0914
# Epoch 35/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3979 - accuracy: 0.0917 - val_loss: 2.3980 - val_accuracy: 0.0895
# Epoch 36/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0897 - val_loss: 2.3979 - val_accuracy: 0.0896
# Epoch 37/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0904 - val_loss: 2.3980 - val_accuracy: 0.0903
# Epoch 38/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0891 - val_loss: 2.3980 - val_accuracy: 0.0896
# Epoch 39/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0913 - val_loss: 2.3980 - val_accuracy: 0.0883
# Epoch 40/40
# 1375/1375 [==============================] - 67s 49ms/step - loss: 2.3980 - accuracy: 0.0906 - val_loss: 2.3979 - val_accuracy: 0.0903
# 688/688 [==============================] - 9s 12ms/step
# Overall test accuracy: {'Overall': 0.09031818181818181}
# 688/688 [==============================] - 8s 11ms/step
# Overall test accuracy: {'Overall': 0.088}
# 2023-05-03 22:32:06.723180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,256]
# 	 [[{{node inp}}]]
# 2023-05-03 22:32:06.754693: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,256]
# 	 [[{{node inp}}]]
# 2023-05-03 22:32:08.327476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,256]
# 	 [[{{node inp}}]]
# 2023-05-03 22:32:08.362229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inp' with dtype float and shape [?,128,256]
# 	 [[{{node inp}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, dropout_98_layer_call_fn, dropout_98_layer_call_and_return_conditional_losses, encoder_layer_44_layer_call_fn, encoder_layer_44_layer_call_and_return_conditional_losses while saving (showing 5 of 139). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_9/model/assets
# INFO:tensorflow:Assets written to: encoder_radio_ML/experiment_9/model/assets
